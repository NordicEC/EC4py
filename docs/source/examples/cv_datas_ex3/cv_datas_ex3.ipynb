# %%
from ec4py import CV_Datas

# %%
# pip install python-dotenv

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
load_dotenv()

projectPath = Path(os.getenv("PROJECT_FOLDER"))
print(projectPath)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 from pathlib import Path
#       4 load_dotenv()
# ----> 6 projectPath = Path(os.getenv("PROJECT_FOLDER"))
#       7 print(projectPath)
#
# File c:\Users\gusta\AppData\Local\Programs\Python\Python313\Lib\pathlib\_local.py:503, in Path.__init__(self, *args, **kwargs)
#     500     msg = ("support for supplying keyword arguments to pathlib.PurePath "
#     501            "is deprecated and scheduled for removal in Python {remove}")
#     502     warnings._deprecated("pathlib.PurePath(**kwargs)", msg, remove=(3, 14))
# --> 503 super().__init__(*args)
#
# File c:\Users\gusta\AppData\Local\Programs\Python\Python313\Lib\pathlib\_local.py:132, in PurePath.__init__(self, *args)
#     130             path = arg
#     131         if not isinstance(path, str):
# --> 132             raise TypeError(
#     133                 "argument should be a str or an os.PathLike "
#     134                 "object where __fspath__ returns a str, "
#     135                 f"not {type(path).__name__!r}")
#     136         paths.append(path)
#     137 # Avoid calling super().__init__, as an optimisation
#
# TypeError: argument should be a str or an os.PathLike object where __fspath__ returns a str, not 'NoneType'

# %%
paths = [
    projectPath / "test_data" /"CV"/"CV_151512_ 3.tdms",
    projectPath / "test_data" /"CV"/"CV_151725_ 3.tdms",
    projectPath / "test_data" /"CV"/"CV_153036_ 3.tdms",
    projectPath / "test_data" /"CV"/"CV_152150_ 3.tdms",
    projectPath / "test_data" /"CV"/"CV_152403_ 3.tdms",
    projectPath / "test_data" /"CV"/"CV_152635_ 3.tdms",
]

datas = CV_Datas(paths)

# %%
datas.plot(legend="rot", savefig="cv_datas_ex3_fig1.png")
# Out:
# <Axes: xlabel='E (V)', ylabel='i (A)'>

# %%
datas.plot("sqrt_rot",legend="rot", savefig="cv_datas_ex3_fig2.png")
# Out:
# <Axes: xlabel='E (V)', ylabel='i ω$^{-0.5}$ (A min$^{0.5}$)'>

# %%
Epot = -0.5
slopes = datas.Levich(Epot, savefig="cv_datas_ex3_fig3.png")
print(slopes[0] )
print(slopes[1] )
# Out:
# $\omega$^0.5 (rpm^0.5)
# $\omega$^0.5 (rpm^0.5)
# Levich analysis
# dir 	pos      	neg
#  :     	A / rpm^0.5 	A / rpm^0.5
# slope: 	-2.57e-05 	-2.54e-05
# -2.569e-05 A rpm^-0.5
# -2.543e-05 A rpm^-0.5

# %%
Epot = -0.5
slopes = datas.Levich(Epot, "area_cm", savefig="cv_datas_ex3_fig4.png")
print(slopes[0] )
print(slopes[1] )
# Out:
# $\omega$^0.5 (rpm^0.5)
# $\omega$^0.5 (rpm^0.5)
# Levich analysis
# dir 	pos      	neg
#  :     	A cm^-2 / rpm^0.5 	A cm^-2 / rpm^0.5
# slope: 	-1.31e-04 	-1.30e-04
# -1.311e-04 A cm^-2 rpm^-0.5
# -1.297e-04 A cm^-2 rpm^-0.5
