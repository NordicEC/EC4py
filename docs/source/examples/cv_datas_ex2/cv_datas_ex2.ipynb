# %%
from ec4py import CV_Datas

# %%
# ! pip install python-dotenv

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
load_dotenv()

projectPath = Path(os.getenv("PROJECT_FOLDER"))
print(projectPath)
# Out:
# C:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py

# %%
paths = [
    projectPath / "test_data" /"CV"/"CV_152635_ 3.tdms",
    projectPath / "test_data" /"CV"/"CV_153036_ 3.tdms"
]

data = CV_Datas(paths)

# %%
import matplotlib.pyplot as plt

# %%
data.plot("sqrt_rot")
# Out:
# C:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_datas.py:233: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   CV_plot.legend()
# <Axes: xlabel='E vs RHE (V)', ylabel='i ω$^{-0.5}$ (A min$^{0.5}$)'>

# %%
Tafel_Range = [-0.03,-0.15]
slopes = data.Tafel(Tafel_Range,savefig="cv_datas_ex2_fig1.png")
print(slopes[0][0], slopes[0][1])
print(slopes[1][0], slopes[1][1] )
# Out:
# -9.520e-02 V/dec -1.068e-01 V/dec
# -5.477e-02 V/dec -5.329e-02 V/dec

# %%
Edl=-0.5
slopes = data.Tafel(Tafel_Range,Edl,savefig="cv_datas_ex2_fig2.png")
print(slopes[0][0], slopes[0][1])
print(slopes[1][0], slopes[1][1] )
# Out:
# -6.461e-02 V/dec -6.110e-02 V/dec
# -5.026e-02 V/dec -4.692e-02 V/dec
