# %%
from ec4py import CV_Data, AREA

# %%
# ! pip install python-dotenv

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
load_dotenv()

projectPath = Path(os.getenv("PROJECT_FOLDER"))
print(projectPath)
# Out:
# C:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py

# %%
from  pathlib import Path
print(Path().cwd())
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\docs\source\examples\cv_data_ex2

# %%
data = CV_Data(projectPath / "test_data" /"CV"/"CV_152635_ 3.tdms")

# %%
import matplotlib.pyplot as plt

# %%
line,p = data.plot()
data.plot(plot = p, y_smooth = 10)
# data.plot(y_smooth = 10)
plt.savefig("cv_data_ex2_fig1.png", dpi='figure', format=None)
# Out:
# 0
# 10

# %%
Tafel_Range = [-0.03,-0.15]
slopes = data.Tafel(Tafel_Range,savefig="cv_data_ex2_fig2.png")
print(slopes[0] )
print(slopes[1] )
# Out:
# 0
# -9.520e-02 V/dec
# -5.477e-02 V/dec

# %%
slopes = data.Tafel(Tafel_Range,-0.4,AREA, savefig="cv_data_ex2_fig3.png")
print(slopes[0] )
print(slopes[1] )
print(data.setup_data._RE)
# Out:
# 0
# -6.456e-02 V/dec
# -5.025e-02 V/dec
# RHE
