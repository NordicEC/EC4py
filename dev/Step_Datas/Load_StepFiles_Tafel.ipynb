# %% [markdown]
# # Tafel analysis notebook for Step data.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
from ec4py import *
from ec4py import Quantity_Value_Unit as QV

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"Step" / "Tafel"
print(path_to_dataSetFolder)
for path in path_to_dataSetFolder.glob("*.tdms"):
    if not path.is_dir():
        paths.append(path)
        print(path)

print()
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095005.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095105.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095206.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095307.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095407.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095508.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095609.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095709.tdms
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Tafel\Steps_095810.tdms
# ...

# %% [markdown]
# ## 3. Load in the data files

# %%
d = Step_Datas(paths)

# %%
d.Tafel(t=30,dt=16, Emin=0.6, Emax=1)
# Out:
# dE = -8.837e-02 V/dec

# %%
d.Tafel(t=60,dt=16, Emin=0.6, Emax=0.92,grids=True)
# Out:
# dE = -1.101e-01 V/dec

# %%
d.Tafel(t=7,dt=16, Emin=0.6, Emax=1,grid=True)
# Out:
# dE = -8.921e-02 V/dec
