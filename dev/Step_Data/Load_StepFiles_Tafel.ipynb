# %% [markdown]
# # Levich and Koutechy-Levich analysis notebook for Step data.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
from ec4py import *
from ec4py import Quantity_Value_Unit as QV

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"Step" / "Rotation"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "Steps_125706.tdms")
paths.append( path_to_dataSetFolder / "Steps_125853.tdms")
paths.append( path_to_dataSetFolder / "Steps_130037.tdms")
paths.append( path_to_dataSetFolder / "Steps_130222.tdms")
paths.append( path_to_dataSetFolder / "Steps_130407.tdms")
paths.append( path_to_dataSetFolder / "Steps_130552.tdms")

print()
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\Step\Rotation

# %% [markdown]
# ## 3. Load in the data files

# %%
d = EC_Data(paths[1])
print(d.channels)
#d.plot("E","Z_E")
e =Step_Data()
e.conv(d)
e.plot()
print(e.nr_of_steps)
f=e.get_step(1)
f.plot()
# Out:
# ['Time', 'E', 'Ucell', 'i', 'Z_E', 'Z_cell', 'Phase_E', 'Phase_cell']
# 11
# (<matplotlib.lines.Line2D at 0x1c57f2e7a50>,
#  <Axes: xlabel='t (s)', ylabel='i (A)'>)

# %%
qs=e.get_steps(3,1)
qs.pop(0)
qs.Tafel([1, 5.5], [0.1, 0.5],-1, )
qs.plot(LEGEND.NONE)
# Out:
# {'plot': <Axes: xlabel='t (s)', ylabel='i (A)'>}

# %%
qs[0].plot(LEGEND.NAME)
# Out:
# (<matplotlib.lines.Line2D at 0x1c511a83e50>,
#  <Axes: xlabel='t (s)', ylabel='i (A)'>)

# %%
d = Step_Data(paths[1])

# %%
d.setup
# Out:
# {'Current Range': '10mA',
#  'Control Mode': 'WE',
#  'Cell Switch': 'TRUE',
#  'Step.Type': 'h; h; h; h; h; h; h; h; h; h; h; ',
#  'Step.E': '0.750; 0.000; -0.050; -0.100; -0.150; -0.200; -0.250; -0.300; -0.350; -0.400; -0.450; ',
#  'Step.Time': '5.000; 10.000; 10.000; 10.000; 10.000; 10.000; 9.000; 10.000; 10.000; 10.000; 10.000; ',
#  'Repetitions': '1',
#  'Method.Duration': '104.0',
#  'Method.Cycle Duration': '104.0',
#  'Method.Avg.Time': '0.01',
#  'AC Frequency': '5.000E+3 Hz',
#  'AC Amplitude': '0.0100 V',
#  'Gas': 'Ar',
#  'Temp_0': '298.15 K',
#  'Temp_1': '298.15 K',
#  'Pressure': '100000 Pa',
#  'Cell Material': 'Glass',
#  'CounterElectrode': 'Pt',
#  'Ref.Electrode': 'Ag/AgCl',
#  'R.solution': '-1.00 Ohm',
#  'IR.compensation': '-1.00 Ohm',
#  'Electrolyte1': '0.001 M_NaClO4: H2O_14',
#  'Electrolyte2': '_: _',
#  'Electrolyte3': '_: _',
#  'Electrode.Material': '',
#  'Electrode.Tip': '',
#  'Electrode.Area': '1.96E-5 m^2',
#  'Electrode.ExElectrode': '',
#  'Electrode.Cat.Loading': '0.00E+0 g m^-2',
#  'Electrode.Cat.Weight': '0.00E+0 g',
#  'Electrode.Cat.totWeight': '0.00E+0 g',
#  'Electrode.Cat.w%': '0.00',
#  'Electrode.Cat.Serial': '',
#  'Electrode.Cat.Batch': '',
#  'Electrode.Cat.Support': '',
#  'Electrode.Cat.Substrate': '',
#  'Note': '',
#  'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp',
#  'Inst.Convection.Speed': '100.0 /min',
#  'Inst.Convection.1': '',
#  'Inst.Convection.1.Speed': '0.0 /min',
#  'Inst.Convection.2': '',
#  'Inst.Convection.2.Speed': '0.0 /min',
#  'Inst.SW0.Value': 'L',
#  'Inst.SW0.Driver': 'Switch DO - ECi-200',
#  'Application.Name': 'EC4 DAQ',
#  'Application.Version': '4.2.142.1',
#  'Lib.InterfacePotentiostat': '1.0.0.68',
#  'Lib.ECi-200': '1.1.43.0',
#  'Lib.Potentiostat_DAQ': '4.1.0.53',
#  'DAQ.Driver_Name': 'DAQmx',
#  'DAQ.Driver_Ver': '16.0.1',
#  'AddOn': '',
#  'DAQ.Device': 'USB-6361 (OEM)',
#  'DAQ.Device.ProductNum': '30107',
#  'DAQ.Device.SerialNum': '27578494',
#  'DAQ.Device.Name': 'Dev2',
#  'DAQ.AO.Channel': 'Dev2/ao0',
#  'DAQ.AO.Sampling': '100000 Hz;10000',
#  'DAQ.AI.Sampling': '30003 Hz;3000',
#  'Inst.Potentiostat': 'ECi-200',
#  'Inst.Potentiostat.Mode': 'WE'}

# %%
d.plot("Time","E")
#print(d.nr_of_steps)

print(d.repetitions)
print(d.step_E,d.step_Type)
# Out:
# 1
# [0.75, 0.0, -0.05, -0.1, -0.15, -0.2, -0.25, -0.3, -0.35, -0.4, -0.45] ['h', 'h', 'h', 'h', 'h', 'h', 'h', 'h', 'h', 'h', 'h']

# %%
print(ds[0].get_pot_offset("RHE"))
ds.plot("area")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(ds[0].get_pot_offset("RHE"))
#       2 ds.plot("area")
#
# NameError: name 'ds' is not defined

# %%
print(ds.Levich(5,2, "area_cm", "RHE", t_end=7 ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(ds.Levich(5,2, "area_cm", "RHE", t_end=7 ))
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\step_datas.py:226, in Step_Datas.Levich(self, Time_s_, step_nr, *args, **kwargs)
#     223 data_kwargs["plot_i"] = data_plot_i
#     224 data_kwargs["plot_E"] = data_plot_E
# --> 226 rot, y, E, y_axis_title, y_axis_unit  = plots_for_rotations(self.datas, Time_s_, step_nr, *args, **data_kwargs)
#     228 # Levich analysis
#     229 B_factor = Levich(rot, y, y_axis_unit, y_axis_title, STYLE_POS_DL, "steps", plot=analyse_plot )
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\step_datas.py:279, in plots_for_rotations(step_datas, time_s_, step_nr, *args, **kwargs)
#     276 index_end = None
#     278 data.norm(args)
# --> 279 data.pot_shift(args)
#     280 #print("AAAAAAAAAAA", str(data.i_unit))
#     281 if rot_kwarge["t_end"] is not None:
#
# AttributeError: 'Step_Data' object has no attribute 'pot_shift'

# %%
#ds.integrate(0,5,3,"RHE")

# %%
#ds[1].pot_shift("RHE")
#print(ds[1].setup["RHE"])
#ds[1].pot_shift("RHE")
ds[1].plot("Time","E" , "area")
# Out:
# (<matplotlib.lines.Line2D at 0x244308a5910>,
#  <Axes: xlabel='t (s)', ylabel='E vs Ag/AgCl (V)'>)

# %%
print(ds[1].integrate(0,10,1,"area_cm", "HE") )
#print(ds[0].integrate(0,10,5,"area"))
#ds[1].plot("area")
# Out:
# -8.751e-05 A cm^-2 s
