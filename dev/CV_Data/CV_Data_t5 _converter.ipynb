# %%
import numpy as np
from pathlib import Path
from ec4py import Quantity_Value_Unit as QV
from ec4py.util_voltammetry import Voltammetry
from ec4py import *
import math

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"CV" / "Start_between_vertex"
print(path_to_dataSetFolder)
paths.append( path_to_dataSetFolder / "CV_104457_30.tdms")
# Out:
# c:\Users\gusta\Documents\GitHub\Python\NordicEC\EC4py\test_data\CV\Start_between_vertex

# %%
a = EC_Data(paths[0])
a.get_channel("Z_E")
# Out:
# (array([1.7592459, 1.7482369, 1.7397493, 1.7028513, 1.692767 , 1.6843286,
#         1.681168 , 1.683346 , 1.7203071, 1.7342474, 1.7356851, 1.7300191,
#         1.7387931, 1.7382733, 1.7053845, 1.6891701, 1.7216703, 1.7331396,
#         1.7610383, 1.7957275, 1.7850323, 1.7586039, 1.7402309, 1.753831 ,
#         1.7361125, 1.7021383, 1.6623774, 1.7067924, 1.7425268, 1.699727 ,
#         1.7751741, 1.7620916, 1.7319843, 1.7783693, 1.715939 , 1.7029132,
#         1.7201141, 1.7088603, 1.7235767, 1.7693614, 1.7483845, 1.7410835,
#         1.7574939, 1.7114376, 1.7738085, 1.7715875, 1.7037225, 1.603826 ,
#         1.5476103, 1.6001344, 1.7487193, 1.865213 , 1.8770243, 1.886926 ,
#         1.8267052, 1.7670811, 1.7378476, 1.7403986, 1.7154706, 1.7757362,
#         1.7789125, 1.8093516, 1.7875402, 1.7670838, 1.7247554, 1.6759127,
#         1.7178398, 1.6837212, 1.7350835, 1.7224869, 1.7671388, 1.7794129,
#         1.7858696, 1.7764454, 1.7666576, 1.7586924, 1.7889214, 1.794087 ,
#         1.8099856, 1.7483045, 1.6694736, 1.596214 , 1.5916314, 1.6668459,
#         1.7548076, 1.7525889, 1.7254333, 1.6886351, 1.6953194, 1.7138063,
#         1.759803 , 1.7551647, 1.7412964, 1.7209858, 1.6886611, 1.6666355],
#        dtype=float32),
#  'Z',
#  'Ohm',
#  0.09998999999999994)

# %%
a = np.append(np.array([3,4,5,6,7,8,0,0]),4)
b = np.where(a>4)
print("b",b)
print(a[a>4])
c = a.nonzero()[0]
print(c.min())
# Out:
# b (array([2, 3, 4, 5], dtype=int64),)
# [5 6 7 8]
# 0

# %%
data = CV_Data(paths[0])
data.plot()
i = data.i_n
i2 = Voltammetry().clean_up_edges(i)

# %%
print(data.integrate(0.4,0.6,POS,AREA,"offset_at_emax"))
data.set_i_at_E_to_zero(0.6)
print(data.integrate(0.4,0.6,AREA,POS))
# Out:
# -1.326e+01 C m^-2
#
# -1.326e+01 C m^-2

# %%
data.integrate(0.4,0.6,POS,"offset_at_emax")
_,p = CV_Data(paths[0]).plot()

# %%
_,p = CV_Data(paths[0], "i", IRCOMP=10).plot(NEG)
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x1e890b71e90>,
#  <Axes: xlabel='E vs SHE (V)', ylabel='i (A)'>)

# %%
_,p = CV_Data(paths[0], IRCOMP="R").plot()
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x1e890c56a50>,
#  <Axes: xlabel='E vs SHE (V)', ylabel='i (A)'>)

# %%
_,p = CV_Data(paths[0], IRCOMP=30).plot()
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x1e890d0ff10>,
#  <Axes: xlabel='E vs SHE (V)', ylabel='i (A)'>)
