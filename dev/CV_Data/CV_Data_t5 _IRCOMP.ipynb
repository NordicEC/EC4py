# %%
import numpy as np
from pathlib import Path
from ec4py import Quantity_Value_Unit as QV
from ec4py import *
import math

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"CV"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\CV

# %%
a = EC_Data(paths[0])
a.get_channel("Z_E")
# Out:
# (array([28.221592 ,  6.815934 , 10.601347 , 42.654514 ,  7.2772484,
#         37.41321  , 44.18743  , 38.795967 , 61.738586 , 21.781277 ,
#         29.692337 , 37.656128 ,  4.071994 ,  6.3731003, 16.627924 ,
#         20.698174 , 14.929827 , 12.3559   , 11.841749 , 16.819923 ,
#          8.430501 , 11.142338 ,  9.021395 , 14.079912 , 12.877802 ,
#          4.7048206, 10.954614 ,  8.614515 , 11.743353 ,  8.418574 ,
#          7.9738417,  7.729176 ,  9.842949 , 17.954247 , 16.21685  ,
#         21.483767 , 15.23032  , 12.04697  , 15.47637  , 21.138693 ,
#          6.5298705, 28.941442 , 17.234192 , 30.551266 , 30.551266 ],
#        dtype=float32),
#  'Z',
#  'Ohm',
#  0.09998999999999994)

# %%
data = CV_Data(paths[0], i="i")

# %%
_,p = CV_Data(paths[0], IRCORR="Z").plot()

# %%
_,p = CV_Data(paths[0], IRCORR="Zmed").plot()
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x1eebf097510>,
#  <Axes: xlabel='E vs RHE (V)', ylabel='i (A)'>)

# %%
_,p = CV_Data(paths[0], "i", IRCORR=50).plot()
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x1eebf183f90>,
#  <Axes: xlabel='E vs RHE (V)', ylabel='i (A)'>)

# %%
_,p = CV_Data(paths[0], IRCORR="Rmed").plot()
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x1eebf4bbb90>,
#  <Axes: xlabel='E vs RHE (V)', ylabel='i (A)'>)

# %%
_,p = CV_Data(paths[0],IRCORR="R").plot(NEG)
CV_Data(paths[0]).plot(plot=p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 _,p = CV_Data(paths[0],IRCORR="R").plot(NEG)
#       2 CV_Data(paths[0]).plot(plot=p)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_data.py:73, in CV_Data.__init__(self, *args, **kwargs)
#      70     return
#      71 else:
#      72     #print(kwargs)
# ---> 73     self.conv(EC_Data(args[0]), *args, **kwargs)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_data.py:323, in CV_Data.conv(self, ec_data, *args, **kwargs)
#     319     return
#     322 self.setup_data = copy.deepcopy(ec_data.setup_data)
# --> 323 self.convert(ec_data.Time,data_E,data_i,**kwargs)
#     324 self.IR_COMPENSATED = ir_comp
#     325 E_title = "E"
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_data.py:487, in CV_Data.convert(self, time, Potential_V, Current_A, **kwargs)
#     484 y_pos =  self.clean_up_edges(y_pos,0)
#     486 if Two_vertex and positive_start:
# --> 487     y_pos2 = self.interpolate(x_u2, y_u2)
#     488     y_pos2 =  self.clean_up_edges(y_pos2,0)
#     489     y_pos = y_pos + y_pos2
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\util_voltammetry.py:152, in Voltammetry.interpolate(self, E_data, y_data)
#     151 def interpolate(self, E_data, y_data ):
# --> 152     return np.interp(self.E, E_data, y_data)
#
# File c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:1663, in interp(x, xp, fp, left, right, period)
#    1660     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1661     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1663 return interp_func(x, xp, fp, left, right)
#
# ValueError: array of sample points is empty

# %%
_,p = CV_Data(paths[0], IRCORR=30).plot()
CV_Data(paths[0]).plot(plot=p)
# Out:
# (<matplotlib.lines.Line2D at 0x2395a2df7d0>,
#  <Axes: xlabel='E vs RHE (V)', ylabel='i (A)'>)
