# %%
# %pip install scipy
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/60.8 kB 871.5 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.8 kB 871.5 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.8 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 293.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.8 MB 653.6 kB/s eta 0:01:09
#    ---------------------------------------- 0.1/44.8 MB 825.8 kB/s eta 0:00:55
#    ---------------------------------------- 0.1/44.8 MB 819.2 kB/s eta 0:00:55
#    ---------------------------------------- 0.1/44.8 MB 774.0 kB/s eta 0:00:58
# ...

# %%
# %pip install pyserial
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ^C
# Note: you may need to restart the kernel to use updated packages.
