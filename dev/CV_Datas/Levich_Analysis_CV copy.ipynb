# %% [markdown]
# # Levich and Koutechy-Levich analysis notebook for CV data.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
from ec4py import *
from ec4py import Quantity_Value_Unit as QV

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"CV"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\NordicEC\EC4py\test_data\CV

# %% [markdown]
# ## 3. Load in the data files

# %%
EC_Data(paths[2]).plot("E","i")
# Out:
# (<matplotlib.lines.Line2D at 0x28590840610>,
#  <Axes: xlabel='Voltage (V)', ylabel='i (A)'>)

# %%
CV_Data(paths[2])

# %%
CVs = CV_Datas(paths)
for cv in CVs:
    #cv.set_area(0.04532, "cm^2")
    print("aa", cv.area)
# Out:
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2

# %%
CVs[1].plot(4,title = "aa")
# Out:
# (<matplotlib.lines.Line2D at 0x28593b6c250>,
#  <Axes: xlabel='E vs RHE (V)', ylabel='i (A)'>)

# %%
#plot = CVs.plot("" ,legend = "name", smooth_y=50)
CVs[1].plot(title = "aa")
for cv in CVs[:1]:
    print(cv.rate)
    cv2 = cv * (1 / 1000.)
    #cv2.plot()

#CVs.bg_corr(CVs)
CVs.plot(AREA, LEGEND.NAME)
CVs[0].plot(AREA, LEGEND.RATE)
bg_corr = CVs.bg_corr(path_to_dataSetFolder / "CV_144913_ 3.tdms" )

#bg_corr.plot()
# Out:
# 5.000e-01 V/s

# %% [markdown]
# ## 4. Levich analysis

# %%
slope1, slope2 = CVs.Levich(-0.5,"area_cm", y_smooth = 11, )
#use the argument to normalize the data
# Out:
# $\omega$^0.5 (rpm^0.5)
# $\omega$^0.5 (rpm^0.5)
# Levich analysis
# dir 	pos      	neg
#  :     	A cm^-2 / rpm^0.5 	A cm^-2 / rpm^0.5
# slope: 	-1.31e-04 	-1.37e-04

# %% [markdown]
# ## 5. Koutechy-Levich analysis

# %%
slope1, slope2 = CVs.KouLev(-0.5,"area", y_smooth = 5)
print(slope1 ** 1, slope1 ** -1)
#use the argument to normalize the data
# Out:
# KouLev analysis
# dir 	pos      	neg
#  : 	rpm^0.5 /A m^-2 	rpm^0.5 /A m^-2
# slope: 	-1.81e-01 	-1.43e-01
# -5.520e+00 A^-1 m^2 rpm^0.2 -1.812e-01 A m^-2 rpm^-0.2

# %%
CVs[0].Tafel([-0.2, -0.1 ],-0.5)
# Out:
# (<ec4py.util.Quantity_Value_Unit at 0x285960de550>,
#  <ec4py.util.Quantity_Value_Unit at 0x2859815f990>)

# %%
CVs.Tafel([-0.2, -0.1 ],-0.5)


#use the argument to normalize the data
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 CVs.Tafel([-0.2, -0.1 ],-0.5)
#       4 #use the argument to normalize the data
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_datas.py:349, in CV_Datas.Tafel(self, lims, E_for_idl, *args, **kwargs)
#     347 Tafel_neg =[]
#     348 for cv in self.datas:
# --> 349     a, b = cv.Tafel(lims, E_for_idl, **cv_kwargs)
#     350     Tafel_pos.append(a)
#     351     Tafel_neg.append(b)
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\cv_data.py:613, in CV_Data.Tafel(self, lims, E_for_idl, *args, **kwargs)
#     593 """_summary_
#     594
#     595 Args:
#    (...)
#     598
#     599 """
#     600 #Tafel_op= {"cv_plot": None,"analyse_plot": None}
#     601 #Tafel_op.update(kwargs)
#     602
#    (...)
#     610 #    CV_plot.title.set_text('CV')
#     611 #    analyse_plot.title.set_text('Tafel Plot')
# --> 613 data_plot,analyse_plot,fig = create_Tafel_data_analysis_plot("CV", **kwargs)
#     615 rot=[]
#     616 y = []
#
# File ~\Documents\GitHub\NordicEC\EC4py\src\ec4py\util_voltammetry.py:367, in create_Tafel_data_analysis_plot(data_plot_title, *args, **kwargs)
#     365     data_plot.title.set_text(data_plot_title)
#     366     analyse_plot.title.set_text('Tafel Plot')
# --> 367 return data_plot,analyse_plot,fig
#
# UnboundLocalError: cannot access local variable 'fig' where it is not associated with a value

# %%
CVs.Tafel([-0.2, -0.1 ],-0.5)
# Out:
# ([<ec4py.util.Quantity_Value_Unit at 0x1fdffb1a110>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdffb20410>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdffbb1490>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdffa2fbd0>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdffaa7e50>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdff5d6e90>],
#  [<ec4py.util.Quantity_Value_Unit at 0x1fdffa79e50>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdffa5abd0>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdffa79b50>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdff621350>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdff29f990>,
#   <ec4py.util.Quantity_Value_Unit at 0x1fdff632dd0>])
